# %% [markdown]
# # Mubasher api documentation

# %% [markdown]
# markets and countries :
#
# {
#   "Egypt" : {"country":"eg",
#              "market":"EGX"},
#
#   "Saudi Arabia" : {"country":"sa",
#                     "market":"TDWL"},
#
#   "Emirates" : {"country":"ae",
#                 "market":"DFM"},
#
#   "Bahrain" : {"country":"bh",
#                "market":"BB"},
#
#   "Oman" : {"country":"om",
#             "market":"MSM"},
#
#   "Qatar" : {"country":"qa",
#              "market":"QE"},
#
#   "Kewait" : {"country":"kw",
#               "market":"BK"},
#
#   "Jordan" : {"country":"jo",
#               "market":"ASE"},
#
#   "Tunisia" : {"country""tn":,
#                "market":"BDT"},
#
#   "Moroco" : {"country":"ma",
#               "market":"CSE"},
#
#   "Palastine" : {"country":"pa",
#               "market":"PEX"},
#
#   "Iraq" : {"country":"iq",
#               "market":"ISX"}
# }
#
# English Host : https://english.mubasher.info/
#
# Arabic Host : https://www.mubasher.info/

# %% [markdown]
# ## General
#
# ### GET /api/1/events?countries=eg&from=2021%2F08%2F28&to=2021%2F09%2F04
#
# arguments :
#
# 1. countries: the target country
# 2. from : the starting date
# 3. to : the end date
#
# ```
# [
#  {'date': '2021-08-29 00:00:00',
#   'events': [
#              {'from': '29 أغسطس 2021',
#               'to': None,
#               'title': 'إجتماع جمعية عامة غير عادية',
#               'host': {
#                   'name': 'الاخوه المتضامنين',
#                   'key': None,
#                   'url': '/markets/EGX/stocks/BSRF'
#                       },
#               'agenda': '- مناقشة جدول الأعمال\n',
#               'markets': {'البورصة المصرية': '/markets/EGX'},
#               'sectors': None,
#               'place': '19 ب ميدان الجزائر - المعادي',
#               'time': '09:00 ص',
#               'announcement': None}
#              ]
#   }
# ]
#
# ```

# %% [markdown]
# ## Statistical api
# ### GET /api/1/analysis/stock-statistics/winners
# arguments :
#
#
# 1.   from : the starting date yyyy/mm/dd
# 2.   to : the end date
# 3.   market : the target market , one of this ["eg","sa","ae","bh","qa","om"]
#
#
#
#
# ### GET /api/1/analysis/stock-statistics/losers
# arguments :
#
#
# 1.   from : the starting date
# 2.   to : the end date
# 3.   market : the target market
#
# ### GET /api/1/analysis/stock-statistics/turnover
# arguemtns:
#
#
# 1.   from : the starting date
# 2.   to : the end date
# 3.   market : the target market
#
# ### GET /api/1/analysis/stock-statistics/volume
# arguments :
#
#
# 1.   from : the starting date
# 2.   to : the end date
# 3.   market : the target market
#
#
#
#
# response :
#
#
# ```
# {'rows': [
#           {'name': "string",
#            'url': 'url',
#            'last': 'number',
#            'previousClose': 'number',
#            'high': 'number',
#            'low': 'number',
#            'changePercentage': 'number%',
#            'volume': 'number',
#            'turnover': 'number',
#            'status': 'string'}
#           ],
# 'numberOfPages': "number",
#  'validCriteria': "bool"}
# ```
#
#
# ### GET /api/1/financial-ratios
# arguments :
#
#
# 1.   exchangeCode : the target exchange code
# 2.   quarter : the target quarter of the year [1:1st, 12: 2nd, 13: 3rd, 14: 4th
#
# ```
# {'rows': [
#           {'name': 'راية',
#            'url': '/markets/EGX/stocks/RAYA/ratios',
#            'previousClose': None,
#            'eps': 0.05183,
#            'peRatio': 50.74281,
#            'bookValue': 0.50249,
#            'pbRatio': 5.23394,
#            'profitMargin': None,
#            'roe': 10.31507,
#            'roa': 0.83708,
#            'inventoryTurnover': None,
#            'currentRatio': 0.99409,
#            'quickRatio': 0.81198,
#            'debtRatio': 47.27873,
#            'netProfitGrowthPercentage': -137.92283,
#            'totalAssetsGrowthPercentage': 61.83094,
#            'bookValueGrowth': -87.81133,
#            'epsPercentageGrowth': -103.79212,
#            'cashFromOperation': -54.88392,
#            'dividendPerShare': 0.045,
#            'cashRatio': 0.10873,
#            'cashEquivalentsAssets': 8.40869,
#            'receivablesMCAP': 123.02277,
#            'cashEquivalentsMCAP': 19.79731,
#            'receivablesAssets': 52.25259,
#            'cashReceivablesAssets': 60.66129,
#            'totalDebtToEquity': 447.96617,
#            'interestCoverageRatio': 1.79544,
#            'date': None,
#            'searchPattern': None,
#            'timestamp': 0,
#            'industrial': True,
#            'regularFinancialYear': True}
#            ],
#   'numberOfPages': 1,
#   'validCriteria': True}
#   ```

# %% [markdown]
# ## Fund boxes
#
# ### GET /api/1/funds
# arguments :
#
# 1.   country : the target country
#
# ```
# {'rows': [
#           {'fundId': 2679,
#            'name': 'صندوق البنك الأهلي المتحد مصر الأول ثروة',
#            'symbol': None,
#            'currency': None,
#            'classification': None,
#            'strategy': None,
#            'fileUrl': None,
#            'market': 'البورصة المصرية',
#            'owner': 'البنك الأهلي المتحد مصر ش.م.م',
#            'country': None,
#            'url': '/countries/EG/funds/2679',
#            'managers': ['هيرمس لإدارة صناديق الاستثمار'],
#            'price': 173.99609,
#            'profitFiveYear': None,
#            'profitThreeYear': None,
#            'profitLastYear': None,
#            'profitYearStart': '11.72%',
#            'profitSixMonth': None,
#            'profitThreeMonth': None,
#            'profitMonth': None,
#            'profitWeek': None,
#            'profitMax52Week': None,
#            'profitMin52Week': None,
#            'date': '17 أكتوبر 2017',
#            'reports': None,
#            'eligibility': None,
#            'establishmentDate': None} ],
#   'numberOfPages': 6,
#   'validCriteria': True}
#   ```

# %% [markdown]
# ## Companies
#
# ### GET /api/1/listed-companies
# arguments :
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
#
# ```
# {'rows': [
#           {'name': 'البنك التجاري الدولي',
#            'url': '/markets/EGX/stocks/COMI',
#            'market': 'البورصة المصرية',
#            'sector': 'بنوك',
#            'marketUrl': None,
#            'currency': None,
#            'profileUrl': '/markets/EGX/stocks/COMI/profile',
#            'symbol': 'COMI',
#            'price': 46.8,
#            'changePercentage': -0.81,
#            'lastUpdate': '29 أغسطس 2021'},  ],
#   'numberOfPages': 14,
#   'validCriteria': True}
# ```
#
# ### GET /api/1/amr
# arguments :
#
#
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
# ```
# {'rows': [
#           {'from': '29 أغسطس 2021',
#            'to': None,
#            'title': 'إجتماع جمعية عامة عادية',
#            'host': {'name': 'الاخوه المتضامنين',
#                     'key': None,
#                     'url': '/markets/EGX/stocks/BSRF'},
#             'agenda': '- مناقشة بنود جدول الأعمال\n',
#             'markets': {'البورصة المصرية': '/markets/EGX'},
#             'sectors': None,
#             'place': '19 ب ميدان الجزائر - المعادي',
#             'time': '08:00 ص',
#             'announcement': None}],
#   'numberOfPages': 2,
#   'validCriteria': True}
#   ```
#
# ### GET /api/1/stocks/prices
# arguments :
#
#
# 1.  country : the target country
#
# ### GET /api/1/stocks/prices/all
# arguments :
#
#
# 1.  country : the target country
#
# ```
# {
#     'lastUpdate': '2021-08-29 14:30:00',
#      'prices': [
#          {'exchange': 'EGX',
#           'name': 'الالومنيوم العربية',
#           'url': '/markets/EGX/stocks/ALUM',
#           'code': 'ALUM',
#           'value': '47.97',
#           'change': '4.36',
#           'changePercentage': '10.00%',
#           'turnover': '3,315,207.00',
#           'open': '43.61',
#           'high': '47.97',
#           'low': '43.00',
#           'volume': '71,356',
#           'status': 'up',
#           'chartFileUrl': None,
#           'updatedAt': '2021-08-29 12:24:59'}
#                 ]
#  }
#
# ```
#
# ### GET /api/1/earnings
# description : Earnings announcments
#
# arguments :
#
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
# 4.  quarter : the target quarter
# 5.  year : the target year of earnings
#
# ```
# {'rows': [
#     {'name': 'مينا للاستثمار السياحي',
#      'url': '/markets/EGX/stocks/MENA',
#      'sector': 'عقارات',
#      'market': 'البورصة المصرية',
#      'quarter': 'الربع الثانى - تراكمي',
#      'year': '2021',
#      'currency': 'جنيه مصري',
#      'marketUrl': '/markets/EGX',
#      'announced': -6228638.0,
#      'changePercentage': 46.22193852816372,
#      'compared': -11582117.0} ],
#  'numberOfPages': 587,
#  'validCriteria': True}
#
# ```
#
# ### GET /api/1/fairValues
# arguments :
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
# 4.  recommendation : type of recommendation [1: buy,
# 2: sell,
# 3: hold,
# 4: reduce,
# 5: neutral,
# 6: accumulate,
# 10: over weight,
# 11: under weight,
# 13: fairly priced,
# 16 : out preform,
# 20 : strong buy]
#
# ```
# {'rows': [
#           {'releasedAt': '11 أغسطس 2021',
#            'name': 'بنك البركة',
#            'url': '/markets/EGX/stocks/SAUD',
#            'source': 'فاروس القابضة',
#            'recommendation': '',
#            'market': 'البورصة المصرية',
#            'sector': 'بنوك',
#            'marketUrl': '/markets/EGX',
#            'value': 15.0,
#            'price': 14.42,
#            'lastPrice': 14.09,
#            'change': 0.5800000000000001,
#            'changePercentage': 4.0221914008321775}
#           ],
#   'numberOfPages': 10078,
#   'validCriteria': True}
# ```
#
# ### GET /api/1/corporate-actions
# arguments :
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
# 4.  type : type of corporate action
# ```
# {'rows': [
#           {'name': 'مصر بنى سويف للأسمنت',
#            'url': '/markets/EGX/stocks/MBSC',
#            'sector': 'مواد البناء',
#            'market': 'البورصة المصرية',
#            'type': 'توزيع أرباح نقدية',
#            'title': 'تاريخ نهاية الحق فىتوزيع أرباح نقدية',
#            'description': 'قررت الجمعية العامة العادية في اجتماعها في 2021-09-05 توزيع 1.5 EGP',
#            'announcement': None,
#            'marketUrl': '/markets/EGX',
#            'announcedAt': '28 مارس 2021',
#            'effectiveFrom': '01 سبتمبر 2021'},
#         ],
#   'numberOfPages': 303,
#   'validCriteria': True}
# ```
#
# ### GET /api/1/insider-trades
# arguments :
# 1.  country : the target country
# 2.  type : 1 for buy, 2 for sell
#
# ```
# {'rows': [
#           {'name': 'الشركة العربية لإدارة وتطوير الأصول',
#            'url': '/markets/EGX/stocks/ACAMD',
#            'trader': 'غير معلن',
#            'type': 'بيع',
#            'market': 'البورصة المصرية',
#            'sector': 'عقارات',
#            'marketUrl': '/markets/EGX',
#            'volume': 8226444,
#            'price': 0.617,
#            'updatedAt': '10 أغسطس 2021'},
#           ],
#   'numberOfPages': 1344,
#  'validCriteria': True}
# ```
#
# ### GET /api/1/capital-increase
# arguments :
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
#
# ```
# {'rows': [
#           {'name': 'كيما',
#            'url': '/markets/EGX/stocks/EGCH',
#            'status': 'سيتم تداولها',
#            'attachment': 'http://data.feedgma.com/mix2/DCMServiceProvider?ROLE=A&RT=87&ID=B3D7F06B-90D6-43B8-8FCE-8FC9431DC501.pdf',
#            'market': 'البورصة المصرية',
#            'sector': 'موارد أساسية',
#            'marketUrl': '/markets/EGX',
#            'volume': 400000000,
#            'price': 5.0,
#            'start': '30 يونيو 2021',
#            'end': '05 أغسطس 2021'}
#           ],
#   'numberOfPages': 13,
#   'validCriteria': True}
# ```
#
# ### GET /api/1/ipos
#
# arguments :
# 1.  country : the target country
# 2.  size : the number of companies in response
# 3.  start : the number that query start from
#
# ```
# {'rows': [
#           {'name': 'ماكرو جروب للمستحضرات الطبية-ماكرو كابيتال',
#            'url': None,
#            'status': 'المنتظره',
#            'attachment': 'http://data.feedgma.com/mix2/DCMServiceProvider?ROLE=A&RT=87&ID=564DA527-D122-4310-B3E2-1B5D5C02F1B7.pdf',
#            'type': 'اولى',
#            'market': 'البورصة المصرية',
#            'sector': 'رعاية صحية و ادوية',
#            'marketUrl': '/markets/EGX',
#            'volume': 13225684,
#            'announcedAt': '06 أبريل 2021'}
#           ],
#   'numberOfPages': 8,
#   'validCriteria': True}
# ```

# %% [markdown]
# # Api implementation

# %%
! pip install dicttoxml
! pip install python-xml2dict
! pip install fsspec
# Out:
# ...
#   Created wheel for dicttoxml: filename=dicttoxml-1.7.4-py3-none-any.whl size=17463 sha256=a3683b0615a187c17ca81182dcacc4a6ff323879870cb809fa37d4cf502f0e2a
#   Stored in directory: /root/.cache/pip/wheels/18/44/5a/c7b93703f611ae3b50820efbaf265413e6b183a56cbec6f661
# Successfully built dicttoxml
# ...
#   Created wheel for python-xml2dict: filename=python_xml2dict-0.1.1-py3-none-any.whl size=2236 sha256=641297707781b59f68254f4f4a4a40bb6e6281ffbae32354c21e3be9a66babf1
#   Stored in directory: /root/.cache/pip/wheels/0a/75/57/0b68bdc59d80dfa2f6d7eb62c13847819d985065b643bbd540
# Successfully built python-xml2dict
# ...
#      |████████████████████████████████| 118 kB 5.0 MB/s
# ...

# %%
from bs4 import BeautifulSoup
import requests
from IPython.display import clear_output
import datetime
import os
from dicttoxml import dicttoxml
from xml.dom.minidom import parseString
import xml2dict
from tabulate import tabulate
import pandas as pd
## in csv files the order : 
## 1: opened - open
## 2: highest - high
## 3: lowest - low
## 4: closed - value
## 5: volume
## ["date","open","high","low","close","volume"]

# %%
class MubasherAPI :
  pass
  def __init__ (self,country):
    self.ROOT = "/content/"
    self.HostURL= "http://www.mubasher.info"
    self.CompaniesAPI="/api/1/listed-companies"
    self.PricesAPI = "/api/1/stocks/prices/all"
    self.HistoricalDirectory = self.ROOT+"historical_data/"
    self.CompaniesDirectory=self.ROOT+"companies_data/"
    self.outputFile =self.CompaniesDirectory+ "companies_database_"+ country+".xml"
    self.dataBase = []
    self.country = country
    self.lastPrices = {}
    self.dataDownloaded = False
  
  def _clearOutput(self):
    for _ in range (10):
      clear_output(wait=True)

  def _GetCompanies(self):
    currentPage = 0
    allPages = 20
    pageSize = 20
    companiesNumber =int(requests.get(self.HostURL + self.CompaniesAPI,params={'country':self.country,'size':1}).json()["numberOfPages"]) 
    while allPages>=currentPage:
      ploads = {'country':self.country,'size':pageSize,'start':currentPage*pageSize}
      r = requests.get(self.HostURL + self.CompaniesAPI,params=ploads)
      response = r.json()
      allPages =int(response["numberOfPages"]) 
      for i in range(len(response["rows"])):
        self._clearOutput()    
        company=response["rows"][i]
        print("importing companies :" + str(i+currentPage*pageSize)+"/"+str(companiesNumber))
        csvPath = ""
        html_doc =requests.get(self.HostURL+company["url"])
        bs = BeautifulSoup(html_doc.text)
        for item in bs.find_all():
          if "historical-data-url" in item.attrs:
            csvPath = item["historical-data-url"]
        dataElement = {"name":company["name"],
                      "url":self.HostURL+company["url"],
                      "csv":csvPath,
                      "symbol":company["symbol"]}
        self.dataBase.append(dataElement)
      currentPage=currentPage+1
    xmlData = dicttoxml(self.dataBase).decode()
    if not (os.path.exists(self.CompaniesDirectory)):
      os.mkdir(self.CompaniesDirectory)
    with open(self.outputFile , "w") as file_object:
      file_object.write(xmlData)
    self._clearOutput() 
    print("Import complete, saved to : "+self.outputFile )

  def DownloadHistorical(self):
    if not (os.path.exists(self.HistoricalDirectory)):
      os.mkdir(self.HistoricalDirectory)
      os.mkdir(self.HistoricalDirectory+self.country+"/")

    for company in self.dataBase:
      r = requests.get(company["csv"], allow_redirects=True)
      open(self.HistoricalDirectory+company["symbol"]+".csv", 'wb').write(r.content)
      self._clearOutput()
      print(company["symbol"]+" data downloaded")
    self._clearOutput()
    print("All historical data downloaded successfully to "+ self.HistoricalDirectory)
    self.dataDownloaded=True

  def LoadCompaines (self):
    if not (os.path.exists(self.outputFile)):
      print("Companies data has not been downloaded yet, starting downloading ..")
      self._GetCompanies()
    f = open(self.outputFile,'r')
    raw_data = f.read()
    self.dataBase=[]
    for item in xml2dict.parse (raw_data)["root"]["item"]:
      self.dataBase.append({"name":item["name"]["#text"],
                          "symbol":item["symbol"]["#text"],
                          "url":item["url"]["#text"],
                          "csv":item["csv"]["#text"]})
    print("Companies data loaded successfully!")
  def UpdatePrices(self):
    self.lastPrices = requests.get(self.HostURL+self.PricesAPI,{"country": self.country}).json()
    print("Prices updated successfully to date " + self.lastPrices["lastUpdate"])

  def ListCompanies(self):
    pass
    table = tabulate([[company["symbol"],company["name"]]for company in self.dataBase], headers=['Symbol', 'Name'], tablefmt='orgtbl')
    print(table)
  def ListCountries(self):
    table = tabulate([["eg","Egypt"],
                      ["sa","Saudi Arabia"],
                      ["ae","Emirates"],
                      ["qa","Qatar"],
                      ["bh","Bahrin"],
                      ["om","Oman"]], headers=['Symbol', 'Name'], tablefmt='orgtbl')
    print(table)

    
  def GetHistoricalData(self,code,startDate,endDate):
    
    if self.dataDownloaded:
      Data=pd.read_csv(self.HistoricalDirectory+self.country+"/"+code+".csv",header=None)
    else :
      Data=pd.read_csv(self._GetCompanyByCode(code)["csv"],header=None)

    startDate =self._FormatDate(startDate) 
    endDate = self._FormatDate(endDate)
    higher_index = Data[Data[0]==endDate]
    lower_index =Data[Data[0]==startDate]
    if lower_index.empty :
      assert print("there is no record for selected start date, please select another date")
    if higher_index.empty:
      assert print ("there is no record for selected end date, please select another date")
    higher_index = higher_index.index[0]
    lower_index =lower_index.index[0]
    return Data[lower_index:higher_index].values.tolist()
    
  
  def _GetCompanyByCode(self,code):
    for company in self.dataBase:
      if company["symbol"]==code:
        return company
    assert print("Invalid company code, please enter a valid company code")
  def _FormatDate ( self,dateToFormat):

    dateArray = dateToFormat.split("-")
    try:
      returnDate = datetime.datetime(int(dateArray[0]),
                              int(dateArray[1]),
                              int(dateArray[2])).strftime("%Y-%m-%d/%H:%M:%S")
    except : 
      assert print ("Invalid date format, please enter a valid date")
    return returnDate

  def SelectCountry(self,contry):
    pass
    if not contry in ["eg","sa","ae","bh","qa","om"]:
      assert print("please select a valid country")
    self.country = country
    self.outputFile =self.CompaniesDirectory+ "companies_database_"+ country+".xml"
    self.HistoricalDirectory = self.ROOT+"historical_data/"+country+"/"
    print("country set to "+country+ ", now getting new selection companies ..")
    self.LoadCompaines()

  def PlotData(dataToPlot):
    fig = go.Figure(data=[go.Candlestick(x=dataToPlot[:][0],
                open=dataToPlot[:][1],
                high=dataToPlot[:][2],
                low=dataToPlot[:][3],
                close=dataToPlot[:][4])])

    fig.show()

# %%
myapi = MubasherAPI("eg")

# %%
myapi.LoadCompaines()
# Out:
# Import complete, saved to : /content/companies_data/companies_database_eg.xml
# Companies data loaded successfully!

# %%
myapi.DownloadHistorical()
# Out:
# All historical data downloaded successfully to /content/historical_data/

# %%
myapi.ListCompanies()

# %%
myapi.UpdatePrices()

# %%
myapi.GetHistoricalData("AITG","2021-06-18","2021-06-24")
